# %%
import pandas as pd

# %%
df=pd.read_csv("/home/abhi/Downloads/Tenure_woe_data.csv")

# %%
df.groupby(["Churn","Tenure"]).count()
# df
# Out:
#               Contract
# Churn Tenure
# No    0             11
#       1            233
#       2            115
#       3            106
#       4             93
#       5             69
#       6             70
#       7             80
#       8             81
#       9             73
#       10            71
#       11            68
#       12            79
#       13            71
#       14            52
#       15            62
#       16            52
#       17            61
#       18            73
#       19            54
#       20            53
#       21            46
#       22            63
#       23            72
#       24            71
#       25            56
#       26            64
#       27            59
#       28            45
#       29            57
# ...                ...
# Yes   43            15
#       44             6
#       45             6
#       46            12
#       47            14
#       48             9
#       49            15
# ...
