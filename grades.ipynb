# %%
import pandas as pd
from datetime import datetime 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/home/abhi/Downloads/grades.csv")
df["timestamp"]=pd.to_datetime(df['submit_time'])
df["extension"]=df["submission"].apply(lambda s:s.split(".")[-1])
len(df[df.extension=='zip']),len(df)
# 189/198
# df["timestamp"].
df['day'] = df['timestamp'].dt.date
# df[df.day>pd.Timestamp(datetime.date(2017, 1, 3))]
# df
df['hour'] = df['timestamp'].dt.hour


hr_df=df.groupby("hour")["hour"].count().reset_index(name="count").sort_values("hour",ascending=False)
hr_df

sns.pointplot(x="hour", y="count", data=hr_df)
# hr_df
