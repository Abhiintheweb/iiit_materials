# %%
from sklearn import linear_model
import pandas as pd


import seaborn as sns

# %%
reg=linear_model.LinearRegression()
# reg.fit()
reg.fit ([[0, 0], [1, 1], [2, 2]], [0, 1, 2])

X=[1,2,3,4,6,9]
y=[3,5,5,4,4,8]

# reg.coef_

df=pd.DataFrame({"X":X,"y":y})
df
sns.regplot(x="X", y="y", data=df)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("tvmarketing.csv")
df.shape
# Out:
# (200, 2)

# %%
sns.pairplot(df,x_vars=["TV"],y_vars="Sales",kind="scatter",size=7, aspect=0.7)

# %%
df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
X=df["TV"]
y=df["Sales"]

from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 , random_state=100)
# Out:
# /home/abhi/venvs/notebook/local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
lr =linear_model.LinearRegression()

# 3. Fit the model using the training data 
#lr.fit([X_train],# y_train)

X_train=np.array([[i]for i in list(X_train)])
X_test=np.array([[i]for i in list(X_test)])

# %%
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
lr.intercept_,lr.coef_
# Out:
# (6.9896658574116799, array([ 0.04649736]))

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
r_squ=r2_score(y_test,y_pred)

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
import matplotlib.pyplot as plt
# Actual vs Predicted
import matplotlib.pyplot as plt
c = [i for i in range(1,61,1)]         # generating index 
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                               # X-label
plt.ylabel('Sales', fontsize=16)                       # Y-label
# Out:
# Text(0,0.5,'Sales')

# %%
df=pd.read_csv("Yield.csv")


sns.pairplot(df,x_vars=["i","Temp"],y_vars="Yield",kind="scatter",size=7, aspect=0.7)

# %%
X=np.array(df.iloc[:,0:2])
y=np.array(df.iloc[:,2])
lr.fit(X,y)
y_pred = lr.predict(X)
mse=mean_squared_error(y,y_pred)
r_squ=r2_score(y,y_pred)
r_squ
# Out:
# 0.19813592325227947
