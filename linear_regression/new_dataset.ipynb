# %%
import numpy as np
import pandas as pd

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm          # Importing statsmodels
#defining a normalisation function 
def normalize (x): 
    return ( (x-np.mean(x))/ (max(x) - min(x)))
                                            
                                              
# applying normalize ( ) to all columns 


# read training data
airquality_train = pd.read_csv("./data/airquality_train.csv")
airquality_train=airquality_train.apply(normalize)
# read test data
airquality_test = pd.read_csv("./data/airquality_test.csv")


# First, create the 'X' and 'Y' objects from the training data.
# You are required to type the indices in the 'iloc' command


# # Type code to subset the predictor columns (X values)
# y_train = airquality_train.iloc[:,1]
# # Type code to subset the response column (Y values)

lr=linear_model.LinearRegression()
lr.predict
# lr.fit(x_train,y_train)


# # Now, go ahead and build the model.
# # First, create the linear regression object
# # You can do this by calling the LinearRegression() class. 
# # If you are unsure about syntax, look up the documentation of sklearn.linear_model



# # Now, run the command for fitting the model
x_test=airquality_test.iloc[:,1:5]
y_test=airquality_test.iloc[:,0]

# output=lr.predict(x_test)
# x_train
X=airquality_train.iloc[:,1:5]
y=airquality_train.iloc[:,0]
lr.fit(X,y)

airquality_test
# Out:
#     Solar.R  Wind  Temp   id
# 0     273.0  11.5    82  105
# 1     291.0  13.8    90   40
# 2      13.0  12.0    67   28
# 3     256.0   9.7    69   12
# 4     322.0  11.5    68   19
# 5     274.0  10.3    82   78
# 6     236.0   9.2    81   64
# 7      19.0  20.1    61    9
# 8     189.0   4.6    93  127
# 9      65.0  13.2    58   15
# 10    207.0   8.0    90  101
# 11    307.0  12.0    66   17
# 12    313.0  11.5    62    4
# 13    115.0   7.4    76  110
# 14    183.0   2.8    93  126
# 15    259.0   9.7    73  133
# 16    190.0  10.3    78  112
# 17    238.0   3.4    81  117
# 18     78.0  18.4    57   18
# 19    267.0   6.3    92   69
# 20    215.0   8.0    86  118
# 21    290.0   9.2    66   13
# 22    220.0  10.3    78  131
# 23    320.0  16.6    73   22
# 24     24.0  10.9    71  137
# 25    127.0   9.7    82   38
# 26    175.0  14.9    81   74
# 27     49.0  10.3    69  147
# 28    139.0  10.3    81  146
# 29    188.0   6.3    94  123
# ..      ...   ...   ...  ...
# ...

# %%
#defining a normalisation function 
def normalize (x): 
    return ( (x-np.mean(x))/ (max(x) - min(x)))
                                            
                                              
# applying normalize ( ) to all columns 
airquality_train = airquality_train.apply(normalize) 
airquality_test = airquality_test.apply(normalize)

# %%
X
x_test
# Out:
#     Wind  Temp   id
# 0   11.5    82  105
# 1   13.8    90   40
# 2   12.0    67   28
# 3    9.7    69   12
# 4   11.5    68   19
# 5   10.3    82   78
# 6    9.2    81   64
# 7   20.1    61    9
# 8    4.6    93  127
# 9   13.2    58   15
# 10   8.0    90  101
# 11  12.0    66   17
# 12  11.5    62    4
# 13   7.4    76  110
# 14   2.8    93  126
# 15   9.7    73  133
# 16  10.3    78  112
# 17   3.4    81  117
# 18  18.4    57   18
# 19   6.3    92   69
# 20   8.0    86  118
# 21   9.2    66   13
# 22  10.3    78  131
# 23  16.6    73   22
# 24  10.9    71  137
# 25   9.7    82   38
# 26  14.9    81   74
# 27  10.3    69  147
# 28  10.3    81  146
# 29   6.3    94  123
# ..   ...   ...  ...
# 59   6.9    78  139
# 60  14.3    80   76
# 61  13.8    67  140
# 62  20.7    72   48
# 63   9.2    71  145
# 64  11.5    85   81
# 65   9.7    61   23
# 66  14.3    72  114
# 67   6.9    81   93
# 68   9.7    80  106
# 69   9.7    97  120
# 70  12.6    64  144
# 71   7.4    82   95
# ...

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# UDF for calculating vif value
def vif_cal(input_data, dependent_col):
    vif_df = pd.DataFrame( columns = ['Var', 'Vif'])
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y,x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        vif_df.loc[i] = [xvar_names[i], vif]
    return vif_df.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False)

# %%
vif_cal(input_data=airquality_train, dependent_col="Ozone")
# Out:
#        Var    Vif
# 2     Temp  17.31
# 1     Wind   6.41
# 0  Solar.R   5.77
# 3       id   5.06

# %%
# Importing matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Let's see the correlation matrix 
plt.figure(figsize = (16,10))     # Size of the figure
sns.heatmap(airquality_train.corr(),annot = True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2bc2798cd4d6> in <module>()
#       3
#       4
# ----> 5 lm_3.predict(y_train)
#
# /home/abhi/venvs/notebook/local/lib/python2.7/site-packages/statsmodels/base/model.pyc in predict(self, exog, transform, *args, **kwargs)
#     852
#     853         predict_results = self.model.predict(self.params, exog, *args,
# --> 854                                              **kwargs)
#     855
#     856         if exog_index is not None and not hasattr(predict_results,
#
# /home/abhi/venvs/notebook/local/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in predict(self, params, exog)
#     343             exog = self.exog
#     344
# --> 345         return np.dot(exog, params)
#     346
#     347     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ...
