# %%
import pandas as pd

# %%
df=pd.read_csv("/home/user-14/Downloads/ML+C2+Know+Your+Cohort.csv")

# %%
import re
df2=df['Years Of Exp'].map(lambda x:re.sub(r'\W+', '', str(x))).dropna()
k=0
count=0
for i in df2.as_matrix():
 if i!='nan':
    if int(i) >= 10:
        k+=int(i)
        count+=1

# %%
float(80)/float(171)
# Out:
# 0.4678362573099415

# %%
float(len(df[df['City']=='Bengaluru']))/float(len(df))
df.groupby('City').count()
# float(82)/float(171)
# Out:
#                              Years Of Exp  Company Name  Job Title  \
# City
# Ahmedabad                               1             1          1
# BANGALORE                               1             1          1
# BENGALURU                               1             1          1
# Bangalore                              28            28         28
# Bangalore, Karnataka, India             7             7          7
# Bengaluru                              48            48         48
# Bengaluru Area, India                   1             1          1
# Bengaluru, Karnataka, India             4             4          4
# Cary                                    1             1          1
# Chandigarh                              1             1          1
# Charlotte                               1             1          1
# Chennai                                 4             4          4
# Delhi                                   4             4          4
# ...

# %%
import numpy as np
m1 = np.array([[ 1, 1 ,3], [ 2, 1 ,9], [ 3, 8 ,8]])
m2 = np.array([[1,2,3]])
np.cross(m1,m2)
m2.shape
# Out:
# (1, 3)
