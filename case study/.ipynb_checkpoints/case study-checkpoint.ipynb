# %%
import pandas as pd

# %%
# test=dict()
# temp=0
# with open("companies.txt") as f:
#     content = f.readlines()
#     for i in content:
        
#         le=len(i.split())
# #         if test.get(le):
# #             test[le]+=1
# #         else:
# #             test[le]=1
#         if le == 11:
#             temp+=1
#             print i.split()
#             print i
# #             print len(i.split(""))
            
#             if temp ==5:
#                 break
            
# # test

# %%
# import urllib2



df=pd.read_csv("companies.txt",error_bad_lines=False,delim_whitespace=True)
# Out:
# Skipping line 3: expected 10 fields, saw 17
# Skipping line 5: expected 10 fields, saw 11
# Skipping line 6: expected 10 fields, saw 11
# Skipping line 7: expected 10 fields, saw 11
# Skipping line 8: expected 10 fields, saw 12
# Skipping line 9: expected 10 fields, saw 13
# Skipping line 10: expected 10 fields, saw 14
# Skipping line 11: expected 10 fields, saw 11
# Skipping line 12: expected 10 fields, saw 12
# Skipping line 13: expected 10 fields, saw 13
# Skipping line 14: expected 10 fields, saw 14
# Skipping line 15: expected 10 fields, saw 12
# Skipping line 16: expected 10 fields, saw 15
# Skipping line 17: expected 10 fields, saw 13
# Skipping line 18: expected 10 fields, saw 14
# Skipping line 19: expected 10 fields, saw 11
# Skipping line 20: expected 10 fields, saw 12
# Skipping line 21: expected 10 fields, saw 12
# Skipping line 22: expected 10 fields, saw 11
# Skipping line 25: expected 10 fields, saw 14
# Skipping line 26: expected 10 fields, saw 13
# ...

# %%
df
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                    /Organization/-The-One-Of-Them-Inc-
# 2                                  /Organization/1000Chi
# 3                                /Organization/1000Lookz
# 4                       /Organization/1001Pharmacies-Com
# 5                                  /Organization/1006-Tv
# 6                                 /Organization/100Du-Tv
# 7                                 /Organization/100E-Com
# 8                                    /Organization/10K-2
# 9                               /Organization/10Tracks-2
# 10                                /Organization/10°North
# 11                       /Organization/115-Network-Disks
# 12                                 /Organization/121Cast
# 13                          /Organization/123Contactform
# 14                             /Organization/123Feng-Com
# ...

# %%
# def find_name(whole_data):
#     print whole_data
#     for i in whole_data:
#         if "hhtp" in i:
#             print i,"===="
#             name=i.split(".")
#             return name[1],i
#     return (None,None)
        
    

# final_data=[]
# with open("companies.txt") as f:
#     content = f.readlines()
#     for i in content:
# #         try:
#             name,url=find_name(i)
#             i=i.split()
#             temp = dict()
#             temp["company_permalink"]=i[0]
#             temp["name"]=name
#             temp["homepage_url"]=url
#             print temp
#             final_data.append(temp)
# #         except Exception as e:
# #             pass     
        
# final_data

# %%
#  mergerd_df.rename(columns={'DRM': 'DistributorRetailerMaster', 'SRM': 'ScreeningRetailerMap','RDM':'RetailerDistributorMaster',"state_x":"state"}, inplace=True)

# %%
df_rounds=pd.read_csv("rounds2.csv")
df_rounds=df_rounds.rename(columns={"company_permalink":"permalink"})

m_df=pd.merge(df,df_rounds,on="permalink",how="outer")

# m_df
# df_rounds.columns
# m_df.describe()
# u_code=list(m_df.permalink)
# for i in u_code:
#     print i.upper().split("ORGANIZATION")[1]
m_df.raised_amount_usd=m_df.raised_amount_usd.fillna(0)
m_df.groupby("funding_round_type").count()
# Out:
#                        permalink  name  homepage_url  category_list  status  \
# funding_round_type
# angel                       6094     0             0              0       0
# convertible_note            1817     0             0              0       0
# debt_financing              6895     0             0              0       0
# equity_crowdfunding         3257     0             0              0       0
# grant                       2200     0             0              0       0
# non_equity_assistance        191     0             0              0       0
# post_ipo_debt                152     0             0              0       0
# post_ipo_equity              638     0             0              0       0
# private_equity              2285     0             0              0       0
# product_crowdfunding         410     0             0              0       0
# secondary_market              95     0             0              0       0
# ...

# %%
m_df.columns
# Out:
# Index([u'permalink', u'name', u'homepage_url', u'category_list', u'status',
#        u'country_code', u'state_code', u'region', u'city', u'founded_at',
#        u'funding_round_permalink', u'funding_round_type',
#        u'funding_round_code', u'funded_at', u'raised_amount_usd'],
#       dtype='object')

# %%
adf_mapping=pd.read_csv("mapping.csv")
df_mapping
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e96c93f5b735> in <module>()
#       1 adf_mapping=pd.read_csv("mapping.csv")
# ----> 2 df_mapping
#
# NameError: name 'df_mapping' is not defined

# %%
m_df
