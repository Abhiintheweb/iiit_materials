# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
spam = pd.read_csv("../SMSSpamCollection.txt", sep = "\t", names=["label", "message"], encoding="utf-8")

# %%
print(spam.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [(u'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', u'ham'), (u'Ok lar... Joking wif u oni...', u'ham'), (u"Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", u'spam'), (u'U dun say so early hor... U c already then say...', u'ham'), (u"Nah I don't think he goes to usf, he lives around here though", u'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()
wordnet_lemmatizer.lemmatize("happily", pos='v')
# Out:
# 'happily'

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [([u'jurong', u'point', u'crazy..', u'available', u'bugis', u'great', u'world', u'buffet', u'...', u'cine', u'get', u'amore', u'wat', u'...'], u'ham'), ([u'lar', u'...', u'joke', u'wif', u'oni', u'...'], u'ham'), ([u'free', u'entry', u'wkly', u'comp', u'win', u'cup', u'final', u'tkts', u'21st', u'may', u'2005.', u'text', u'87121', u'receive', u'entry', u'question', u'std', u'txt', u'rate', u'apply', u'08452810075over18'], u'spam'), ([u'dun', u'say', u'early', u'hor', u'...', u'already', u'say', u'...'], u'ham'), ([u'nah', u"n't", u'think', u'usf', u'live', u'around', u'though'], u'ham')]

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8395

# %% [markdown]
# ### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({u'contains(ffffuuuuuuu)': False, u'contains(waste)': False, u'contains(andre)': False, u'contains(my-tone.com/enjoy)': False, u'contains(dha)': False, u'contains(upd8)': False, u'contains(2channel)': False, u'contains(rent)': False, u'contains(tue)': False, u'contains(oops)': False, u'contains(8007)': False, u'contains(sender)': False, u'contains(everywhere)': False, u'contains(09061749602)': False, u'contains(case)': False, u'contains(542)': False, u'contains(s..antha)': False, u'contains(mon.l8rs.x)': False, u'contains(slap)': False, u'contains(ros)': False, u'contains(alright.okay)': False, u'contains(ready)': False, u'contains(wiv)': False, u'contains(withdraw)': False, u'contains(stone..)': False, u'contains(venugopal)': False, u'contains(kiefer.com)': False, u'contains(rodds1)': False, u'contains(-xx)': False, u'contains(elections)': False, u'contains(inmind)': False, u'contains(gnt)': False, u'contains(proove)': False, u'contains(postpone)': False, u'contains(*adoring)': False, u'contains(dear..)': False, u'contains(arty)': False, u'contains(now.i)': False, u'contains(.lovable)': False, u'contains(laurie)': False, u'contains(lily)': False, u'contains(teeth)': False, u'contains(thinkthis)': False, u'contains(weightloss)': False, u'contains(she.s)': False, u'contains(.take)': False, u'contains(fan)': False, u'contains(visit)': False, u'contains(weeks)': False, u'contains(08712404000)': False, u'contains(comment)': False, u'contains(downstem)': False, u'contains(dimension)': False, u'contains(compass)': False, u'contains(gal)': False, u'contains(87121)': False, u'contains(prescription)': False, u'contains(aah)': False, u'contains(that..)': False, u'contains(sorrow)': False, u'contains(compensation)': False, u'contains(feature)': False, u'contains(sary)': False, u'contains(bcaz)': False, u'contains(resume)': False, u'contains(maniac)': False, u'contains(\xa3150)': False, u'contains(shortage)': False, u'contains(suck)': False, u'contains(3miles)': False, u'contains(it.i)': False, u'contains(humanities)': False, u'contains(lifetime)': False, u'contains(excuse)': False, u'contains(hex)': False, u'contains(god..)': False, u'contains(switch)': False, u'contains(srs)': False, u'contains(rain)': False, u'contains(2.naughty)': False, u'contains(fyi)': False, u'contains(brolly)': False, u'contains(crazy)': False, u'contains(80155)': False, u'contains(antelope)': False, u'contains(dearer)': False, u'contains(noline)': False, u'contains(74355)': False, u'contains(2moro)': False, u'contains(2kbsubject)': False, u'contains(genus)': False, u'contains(boltblue)': False, u'contains(tscs087147403231winawk)': False, u'contains(amt)': False, u'contains(11.48)': False, u'contains(2stoptx)': False, u'contains(reaction)': False, u'contains(fedex)': False, u'contains(bthere)': False, u'contains(+449071512431)': False, u'contains(jaz)': False, u'contains(lobby)': False, u'contains(anythingtomorrow)': False, u'contains(linear)': False, u'contains(saibaba)': False, u'contains(08002988890)': False, u'contains(specialisation)': False, u'contains(cooperative)': False, u'contains(rally)': False, u'contains(09050280520)': False, u'contains(shoot)': False, u'contains(gailxx)': False, u'contains(hey..)': False, u'contains(director)': False, u'contains(etc)': False, u'contains(heavy)': False, u'contains(thm)': False, u'contains(7876150ppm)': False, u'contains(nvq)': False, u'contains(uni)': False, u'contains(25p)': False, u'contains(sumfing)': False, u'contains(tyrone)': False, u'contains(nver)': False, u'contains(watch)': False, u'contains(unemployed)': False, u'contains(june)': False, u'contains(0871212025016)': False, u'contains(witout)': False, u'contains(toclaim)': False, u'contains(anna)': False, u'contains(pobox1)': False, u'contains(meatballs)': False, u'contains(flag)': False, u'contains(sundayish)': False, u'contains(0906346330.)': False, u'contains(flood)': False, u'contains(evrydy)': False, u'contains(henry)': False, u'contains(9153.)': False ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# ('Training set size : ', 4457)
# ('Test set size : ', 1115)

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.993044648867

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.980269058296

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# ('Classification result : ', u'spam')

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contains(award) = True             spam : ham    =    202.9 : 1.0
#           contains(code) = True             spam : ham    =    119.2 : 1.0
#          contains(nokia) = True             spam : ham    =    101.6 : 1.0
#          contains(await) = True             spam : ham    =     98.3 : 1.0
#         contains(urgent) = True             spam : ham    =     95.9 : 1.0
#       contains(delivery) = True             spam : ham    =     81.6 : 1.0
#            contains(txt) = True             spam : ham    =     80.2 : 1.0
#       contains(landline) = True             spam : ham    =     74.0 : 1.0
#        contains(private) = True             spam : ham    =     73.2 : 1.0
#      contains(statement) = True             spam : ham    =     64.8 : 1.0
#        contains(service) = True             spam : ham    =     62.2 : 1.0
#          contains(final) = True             spam : ham    =     60.6 : 1.0
#          contains(video) = True             spam : ham    =     59.0 : 1.0
#        contains(voucher) = True             spam : ham    =     56.5 : 1.0
#         contains(latest) = True             spam : ham    =     52.9 : 1.0
#            contains(opt) = True             spam : ham    =     52.3 : 1.0
#            contains(100) = True             spam : ham    =     52.3 : 1.0
#         contains(caller) = True             spam : ham    =     52.3 : 1.0
#          contains(apply) = True             spam : ham    =     51.1 : 1.0
#        contains(attempt) = True             spam : ham    =     46.4 : 1.0
#         contains(player) = True             spam : ham    =     43.9 : 1.0
#           contains(quiz) = True             spam : ham    =     43.9 : 1.0
#         contains(camera) = True             spam : ham    =     43.9 : 1.0
#         contains(mobile) = True             spam : ham    =     42.9 : 1.0
#            contains(box) = True             spam : ham    =     42.5 : 1.0
#         contains(orange) = True             spam : ham    =     40.3 : 1.0
#            contains(rat) = True             spam : ham    =     39.7 : 1.0
#           contains(comp) = True             spam : ham    =     39.7 : 1.0
#          contains(pound) = True             spam : ham    =     36.7 : 1.0
#           contains(land) = True             spam : ham    =     36.4 : 1.0
#         contains(direct) = True             spam : ham    =     35.6 : 1.0
#           contains(info) = True             spam : ham    =     33.9 : 1.0
#        contains(network) = True             spam : ham    =     32.8 : 1.0
#           contains(draw) = True             spam : ham    =     32.5 : 1.0
#           contains(user) = True             spam : ham    =     31.4 : 1.0
#       contains(customer) = True             spam : ham    =     31.4 : 1.0
#         contains(txting) = True             spam : ham    =     31.4 : 1.0
#            contains(del) = True             spam : ham    =     31.4 : 1.0
#        contains(auction) = True             spam : ham    =     31.4 : 1.0
#          contains(offer) = True             spam : ham    =     30.4 : 1.0
#          contains(fancy) = True             spam : ham    =     28.9 : 1.0
#           contains(cash) = True             spam : ham    =     28.6 : 1.0
#        contains(england) = True             spam : ham    =     27.2 : 1.0
#           contains(line) = True             spam : ham    =     26.4 : 1.0
#        contains(contact) = True             spam : ham    =     25.8 : 1.0
#        contains(receive) = True             spam : ham    =     25.6 : 1.0
#            contains(per) = True             spam : ham    =     25.4 : 1.0
#         contains(select) = True             spam : ham    =     24.5 : 1.0
#         contains(todays) = True             spam : ham    =     24.2 : 1.0
#       contains(motorola) = True             spam : ham    =     23.8 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# ('Classifier stored at ', 'nb_spam_classifier.pickle')
