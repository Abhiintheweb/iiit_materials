# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,"hi"])

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
print(df.describe())
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
df.columns
# Out:
# (517, 13)

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
# df_2 = #Type your code here
# print(df_2.head())
df.sort_values(['month','day'],ascending=True)
# df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain    area
# 241  4  4   apr  fri  83.0   23.3   85.3   2.3  16.7  20   3.1   0.0    0.00
# 442  6  5   apr  mon  87.9   24.9   41.6   3.7  10.9  64   3.1   0.0    3.35
# 19   6  4   apr  sat  86.3   27.4   97.1   5.1   9.3  44   4.5   0.0    0.00
# 239  7  5   apr  sun  81.9    3.0    7.9   3.5  13.4  75   1.8   0.0    0.00
# 469  6  3   apr  sun  91.0   14.6   25.6  12.3  13.7  33   9.4   0.0   61.13
# 470  5  4   apr  sun  91.0   14.6   25.6  12.3  17.6  27   5.8   0.0    0.00
# 176  6  5   apr  thu  81.5    9.1   55.2   2.7   5.8  54   5.8   0.0    4.61
# 196  6  5   apr  thu  81.5    9.1   55.2   2.7   5.8  54   5.8   0.0   10.93
# 240  6  3   apr  wed  88.0   17.2   43.5   3.8  15.2  51   2.7   0.0    0.00
# 12   6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0    0.00
# 78   1  2   aug  fri  90.1  108.0  529.8  12.5  14.7  66   2.7   0.0    0.00
# ...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df[['month', 'day', 'temp', 'area']]
# Out:
#     month  day  temp   area
# 0     mar  fri   8.2   0.00
# 1     oct  tue  18.0   0.00
# 2     oct  sat  14.6   0.00
# 3     mar  fri   8.3   0.00
# 4     mar  sun  11.4   0.00
# 5     aug  sun  22.2   0.00
# 6     aug  mon  24.1   0.00
# 7     aug  mon   8.0   0.00
# 8     sep  tue  13.1   0.00
# 9     sep  sat  22.8   0.00
# 10    sep  sat  17.8   0.00
# 11    sep  sat  19.3   0.00
# 12    aug  fri  17.0   0.00
# 13    sep  mon  21.3   0.00
# 14    sep  wed  26.4   0.00
# 15    sep  fri  22.9   0.00
# 16    mar  sat  15.1   0.00
# 17    oct  mon  16.7   0.00
# 18    mar  wed  15.9   0.00
# 19    apr  sat   9.3   0.00
# 20    sep  tue  18.3   0.00
# 21    sep  mon  19.1   0.00
# 22    jun  sun  21.0   0.00
# 23    aug  sat  19.5   0.00
# 24    aug  sat  23.7   0.00
# 25    aug  sun  16.3   0.00
# 26    sep  fri  19.0   0.00
# 27    sep  mon  19.4   0.00
# 28    sep  sat  30.2   0.00
# 29    sep  sun  22.8   0.00
# ..    ...  ...   ...    ...
# 487   aug  tue  26.4  16.40
# ...

# %%
df.loc[0::2]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# 12   6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0   0.00
# 14   6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0   0.00
# 16   5  5   mar  sat  91.7   35.8   80.8   7.8  15.1  27   5.4   0.0   0.00
# 18   6  4   mar  wed  89.2   27.9   70.8   6.3  15.9  35   4.0   0.0   0.00
# 20   6  4   sep  tue  91.0  129.5  692.6   7.0  18.3  40   2.7   0.0   0.00
# ...

# %%
# x=df.set_index("X",inplace=True)
# x
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')


# df2=df.set_index("X",inplace=True)
type(df.set_index("X",inplace=True))
# Out:
# NoneType

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df_2 =df.iloc[2:21,] #Type your code for indexing using iloc

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df.loc[(df.area>0 ) & (df.wind >1)]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain    area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0    0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0    0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0    0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0    0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0    0.61
# 143  1  2   jul  sat  90.0   51.3  296.3   8.7  16.6  53   5.4   0.0    0.71
# 144  2  5   aug  wed  95.5   99.9  513.3  13.2  23.8  32   5.4   0.0    0.77
# 145  6  5   aug  thu  95.2  131.7  578.8  10.4  27.4  22   4.0   0.0    0.90
# 146  5  4   mar  mon  90.1   39.7   86.6   6.2  13.2  40   5.4   0.0    0.95
# 147  8  3   sep  tue  84.4   73.4  671.9   3.2  24.2  28   3.6   0.0    0.96
# 148  2  2   aug  tue  94.8  108.3  647.1  17.0  17.4  43   6.7   0.0    1.07
# ...

# %%
import pandas as pd
df_1 = pd.read_csv('https://query.data.world/s/vv3snq28bp0TJq2ggCdxGOghEQKPZo')
df_2 = pd.read_csv('https://query.data.world/s/9wVKjNT0yiRc3YbVJaiI8a6HGl2d74')
# df_3 = #Type your code here.
# print(df_3.head(20))
pd.merge(df_1,df_2,on="unique_id",how='inner')
# df_2
# Out:
#                                          name                       address  \
# 0                   arnie morton's of chicago     "435 s. la cienega blvd."
# 1                                  art's deli         "12224 ventura blvd."
# 2                               bel-air hotel        "701 stone canyon rd."
# 3                                  cafe bizou         "14016 ventura blvd."
# 4                                   campanile         "624 s. la brea ave."
# 5                             chinois on main               "2709 main st."
# 6                                      citrus           "6703 melrose ave."
# 7                         fenix at the argyle           "8358 sunset blvd."
# 8                                     granita         "23725 w. malibu rd."
# 9                                  grill  the             "9560 dayton way"
# 10                                      katsu         "1972 hillhurst ave."
# ...

# %%
import pandas as pd
df_1 = pd.read_csv('https://query.data.world/s/vv3snq28bp0TJq2ggCdxGOghEQKPZo')
df_2 = pd.read_csv('https://query.data.world/s/9wVKjNT0yiRc3YbVJaiI8a6HGl2d74')
# df_3 =#Type your code here.
pd.concat([df_1,df_2],axis=0)
# Out:
#                         address               address_2              city  \
# 0     "435 s. la cienega blvd."                     NaN     "los angeles"
# 1         "12224 ventura blvd."                     NaN     "studio city"
# 2        "701 stone canyon rd."                     NaN         "bel air"
# 3         "14016 ventura blvd."                     NaN    "sherman oaks"
# 4         "624 s. la brea ave."                     NaN     "los angeles"
# 5               "2709 main st."                     NaN    "santa monica"
# 6           "6703 melrose ave."                     NaN     "los angeles"
# 7           "8358 sunset blvd."                     NaN    "w. hollywood"
# 8         "23725 w. malibu rd."                     NaN          "malibu"
# 9             "9560 dayton way"                     NaN   "beverly hills"
# 10        "1972 hillhurst ave."                     NaN       "los feliz"
# 11    "903 n. la cienega blvd."                     NaN    "w. hollywood"
# ...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
#Type your groupby command here

df1=df.groupby(["month","day"])

df_1 = df1["rain","wind"].mean() #Type your code to find the mean of columns 'rain' and 'wind'
# print(df_1.head(20))

df_1["test"]=df_1.wind.apply(lambda c: "hi")
df_1
# Out:
#                rain      wind test
# month day
# apr   fri  0.000000  3.100000   hi
#       mon  0.000000  3.100000   hi
#       sat  0.000000  4.500000   hi
#       sun  0.000000  5.666667   hi
#       thu  0.000000  5.800000   hi
#       wed  0.000000  2.700000   hi
# aug   fri  0.066667  4.766667   hi
#       mon  0.000000  2.873333   hi
#       sat  0.000000  4.310345   hi
#       sun  0.025000  4.417500   hi
#       thu  0.000000  3.503846   hi
#       tue  0.300000  4.567857   hi
#       wed  0.000000  3.520000   hi
# dec   fri  0.000000  4.900000   hi
#       mon  0.000000  8.500000   hi
#       sun  0.000000  8.500000   hi
#       thu  0.000000  4.900000   hi
#       tue  0.000000  8.500000   hi
#       wed  0.000000  8.000000   hi
# feb   fri  0.000000  4.820000   hi
#       mon  0.000000  4.500000   hi
#       sat  0.000000  2.350000   hi
#       sun  0.000000  2.550000   hi
#       thu  0.000000  3.100000   hi
#       tue  0.000000  5.850000   hi
# ...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
# df['XY'] = #Type your code here.
# print(df.head(20))
df["XY"]=df["X"]*df["Y"]
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
# # df_1 = #Type your code here. 
# # print(df_1.head(20))

# df.pivot_table(values=["month","day"],index=["month","day"] ,aggfunc="mean")
# df = pd.DataFrame({"a": [1,2,3,1,2,3], "b":[1,1,1,2,2,2], "c":np.random.rand(6)})
pd.pivot_table(df, index=["month","day"], values= ["rain","wind"], aggfunc=np.mean)
# Out:
#                rain      wind
# month day
# apr   fri  0.000000  3.100000
#       mon  0.000000  3.100000
#       sat  0.000000  4.500000
#       sun  0.000000  5.666667
#       thu  0.000000  5.800000
#       wed  0.000000  2.700000
# aug   fri  0.066667  4.766667
#       mon  0.000000  2.873333
#       sat  0.000000  4.310345
#       sun  0.025000  4.417500
#       thu  0.000000  3.503846
#       tue  0.300000  4.567857
#       wed  0.000000  3.520000
# dec   fri  0.000000  4.900000
#       mon  0.000000  8.500000
#       sun  0.000000  8.500000
#       thu  0.000000  4.900000
#       tue  0.000000  8.500000
#       wed  0.000000  8.000000
# feb   fri  0.000000  4.820000
#       mon  0.000000  4.500000
#       sat  0.000000  2.350000
#       sun  0.000000  2.550000
#       thu  0.000000  3.100000
#       tue  0.000000  5.850000
#       wed  0.000000  3.100000
# jan   sat  0.000000  3.100000
#       sun  0.000000  0.900000
# jul   fri  0.000000  4.300000
# ...

# %%
import pandas as pd

pd.read_csv("/home/user-14/Desktop/data/desai.csv",sep=None,engine = 'python' )
# Out:
#      distributor_id distributor_retailer_code
# 0                 6                     P7786
# 1                 6                    P03095
# 2                 6                    P01088
# 3                 6                    P07508
# 4                 6                    P08300
# 5                 6                    P05780
# 6                 6                    P07391
# 7                 6                    P04875
# 8                 6                    P08950
# 9                 6                    P00762
# 10                6                     21092
# 11                6                     44135
# 12                6                     P1241
# 13                6                     P1234
# 14                6                    P07982
# 15                6                    P04358
# 16                6                     P0369
# 17                6                    P09890
# 18                6                    P04761
# ...

# %%
import pandas as pd
import PyPDF2

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/Hfu_PsEuD1Z_yJHmGaxWTxvkz7W_b0')
# print(#Type your code here.)

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/Hfu_PsEuD1Z_yJHmGaxWTxvkz7W_b0')
# print(round(#Type your code here))#Round off percentage values to 2 decimial places.
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
100*(df.isnull().sum()/len(df.index))
# Out:
# Ord_id                 0.000000
# Prod_id                0.000000
# Ship_id                0.000000
# Cust_id                0.000000
# Sales                  0.238124
# Discount               0.654840
# Order_Quantity         0.654840
# Profit                 0.654840
# Shipping_Cost          0.654840
# Product_Base_Margin    1.297774
# dtype: float64

# %%
df=df[df.isnull().sum(axis=1)<=5]
100*(df.isnull().sum()/len(df.index))
# Out:
# Ord_id                 0.000000
# Prod_id                0.000000
# Ship_id                0.000000
# Cust_id                0.000000
# Sales                  0.000000
# Discount               0.417711
# Order_Quantity         0.417711
# Profit                 0.417711
# Shipping_Cost          0.417711
# Product_Base_Margin    1.062179
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/Hfu_PsEuD1Z_yJHmGaxWTxvkz7W_b0')
# print(round(#Type your code here))#Round off percentage values to 2 decimial places.
# df

# %%
# df1=df[df["Product_Base_Margin"].isnull()]
# df1["Product_Base_Margin"].fillna(df["Product_Base_Margin"].mean())
mean_val=round(df["Product_Base_Margin"].mean(),2)
df.Product_Base_Margin=df.Product_Base_Margin.fillna(mean_val)
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...
